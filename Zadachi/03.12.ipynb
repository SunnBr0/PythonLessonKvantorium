# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cash = int(input("Сколько денег всего: "))
price = 38 * 2.5
cashback= cash - price
if cash < price:
    print("Недостаточно денег")
else:
    print(cashback)
# Out:
# 5.0

# %%
money = int(input("Сколько денег: "))
moneyCherry = 38
massCherry = 2.5
formula = money - massCherry*moneyCherry
if money<massCherry*moneyCherry:
    print("Не хватает денег на 2.5кг черешни")
else:
    print(formula)
# Out:
# Не хватает денег на 2.5кг

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nameTovar = input("Введите название товара: ")
namePrice = int(input("Введите цену: "))
massTovar = int(input("Введите вес товара: "))
cash = int(input("Деньги : "))
print("Чек")
print(f"{nameTovar} - {massTovar}кг - {namePrice}руб/кг")
end = namePrice * massTovar
print(f"Итого: {end}руб")
print(f"Внесено: {cash}руб")
cashback = cash - end
if cash < end:
    print("Недостаточно")
else:
    print(f"Сдача: {cashback}руб")
# Out:
# Чек
# чай - 5кг - 10руб/кг
# Итого: 50руб
# Внесено: 200руб
# Сдача: 150руб

# %%
nameTovar = input("Название товара: ")
priceTovar = int(input("Цена товара: "))
massTovar = int(input("Масса товара: "))
money = int(input("Кол-во денег: "))
print("Чек")
print(nameTovar,"-",massTovar,"кг","-",priceTovar,"руб/кг")
print("Итого: ",priceTovar*massTovar,"руб")
print("Внесено:",money,"руб")
if money < massTovar*priceTovar:
    print("денег не хватает,берём кредит")
else:
    print("Сдача:",money - massTovar*priceTovar,"руб")
# Out:
# Чек
# лимонад - 8 кг - 54 руб/кг
# Итого:  432 руб
# Внесено: -20 руб
# денег не хватает,берём кредит

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = input("Имя ребёнка: ")
number = input("Номер шкафа: ")
group = number[0]
bed = number[1]
list = number[2]
print("Группа№",group)
print(list,".",name)
print("Шкафчик:",number)
print("Кроватка:",bed,".")
# Out:
# Группа№ 5
# 1 . Бронислав
# Шкафчик: 571
# Кроватка: 7 .

# %%
name = input("Имя ребёнка: ")
number = int(input("Номер шкафчика: "))
group = str(number)[0]
print(f"Группа №{group}")
spisok = str(number)[2]
print(f"{spisok}. {name}.")
print(f"Шкафчик: {number}.")
bad = str(number)[1]
print(f"Кроватка: {bad}.")
# Out:
# Группа №3
# 8. Маша.
# Шкафчик: 358.
# Кроватка: 5.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = int(input("км до A: "))
B = int(input("км до B: "))
C = int(input("Скорость: "))
S  = B- A
T = S/C
print(T)
# Out:
# 3.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nameVelocityPeti = int(input("Скорость")) 
nameVelocityVacy = int(input("Скорость")) 
if nameVelocityPeti > nameVelocityVacy :
    print("Победил петя")
else:
    print("победил вася")
# Out:
# победил вася

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = float(input("Координата x: "))
y= float(input("Координата y: "))
if x**2 + y**2 > 100:
    print("Ушли в море нас съедят акулы")
elif x>=0 and y>=0 and x**2+y**2 < 25:
    print("Опасность ! Покиньте зону !")
elif -4 <= x < 0 and 0 <=y <=5 :
    print("Опасность ! Покиньте зону !")
elif -7<=x < -4 and 0<=y<=5 and y <7/5 +5:
    print("Опасность ! Покиньте зону !")
elif 0.25 * x ** 2 + 0.5 * x - 8.75 <= y <= 0:
    print("Опасность ! Покиньте зону !")
else:
    print("Хорошо всё ")
# Out:
# Опасность ! Покиньте зону !
