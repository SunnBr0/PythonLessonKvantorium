# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #1 Задание
# Написать форму ,которая спрашивает ваше имя,фамилию,отчество и выводило сообщение "Приветствую ФИО"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Рассказывать про типы данных. Рассказать неизменяемые типы данных. И сделать пару операций с числами

# %% [markdown]
# Рассказать про константы

# %% [markdown]
# #2 Задание
# #2.1 При х = 10 посчитайте y = 2x + 3x - 5
#
# #* При х = 10 посчитайте y = 2(x-10)^2 + 3(x+2) - 5
#
# #** При х = 10 посчитайте y = 2(x-10)^2 + 3(x^(-2))^2 - 5
#
# #2.2 При PI =3.14 и r=12 посчитать площадь круга S = PI*r^2
# # и длину окружности L = 2 * PI * r
# #* При длинны окружности L = 24  надо найти r
# #** При площади круга S = 25 надо найти r^2

# %%
print("Hello world")
name = "Vova"
lastName = "Voronov"
print(name,lastName)
print("Меня зовут: ",name,lastName,"Дмитриевич")
print(f"У меня есть имя: {name} и есть фамилия: {lastName} ")
print("Меня зовут: "+name+lastName+"Дмитриевич")

# %%
name = input("Как вас по имени: ")
print(name)
# Написать форму ,которая спрашивает ваше имя,фамилию,отчество
# и выводило сообщение "Приветствую ФИО"
# Ввод:
# Вова
# Воронов
# Дмитриевич
# Вывод : "Приветствую Воронов Вова Дмитриевич"

# %%
valueX = 10
valueY = 3
sum = valueY +valueX
raznost = valueY - valueX
powValue = valueY* valueX
devValue = valueY/ valueX
print(sum,raznost,powValue,devValue)
stepValue = valueX ** valueY
modValue = valueX % valueY
devtwoValue = valueX // valueY
print(stepValue,modValue,devtwoValue)
print(type(devValue))
PI = 3.14

# %%
# Решение 2
# Решение 2.1
valueX = 10
valueY = 2*(valueX**2) + 3*valueX - 5
print("2.1: ", valueY)
# Решение 2.1 *
valueX = 10
valueY = 2*((valueX-10)**2) + 3*(valueX + 2) - 5
print("2.1(*): ", valueY)
# Решение 2.1 **
valueX = 10
valueY = 2*((valueX-10)**2) + 3*((valueX**(-2))**2) - 5
print("2.1(**): ", valueY)
# Out:
# 2.1:  225
# 2.1(*):  31
# 2.1(**):  -4.9997

# %%
# Решение 2.2

print("2.1(**): ", valueY)
