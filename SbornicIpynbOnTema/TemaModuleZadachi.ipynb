# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#(a-b)*(a+b) = a^2 - b^2
from math import pow
a = 10
b = 5
valueLeft = (a-b)*(a+b)
valueRight = pow(a,2)-pow(b,2)
print("(a-b)*(a+b): ",valueLeft)
print(" a^2 - b^2: ",valueRight)
# Out:
# (a-b)*(a+b):  75
#  a^2 - b^2:  75.0
